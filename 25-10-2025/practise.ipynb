# %%
age=18
print(age)
print(type(age))

if age==16:
    print('equal')
else:
    print('not equal')

name='chetan'
if name=='chetan':
    print('names r equal')
# Out:
# 18
# <class 'int'>
# not equal
# names r equal

# %%
emp_names=['amit','rajesh','raju']
print(type(emp_names))
print(len(emp_names))
# Out:
# <class 'list'>
# 3

# %%
#tuple
student_details=(1,"ishan","pune",411014, 41.5)
print(len(student_details))

for item in student_details:
    print(item)
# Out:
# 5
# 1
# ishan
# pune
# 411014
# 41.5
