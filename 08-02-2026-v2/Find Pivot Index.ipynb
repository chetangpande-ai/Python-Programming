# %% [markdown]
# ### LeetCode - Find Pivot Index

# %%
#define array
mum = [71, 34, 3, 41, 5]
print(type(mum))

for i in mum:
    print(i)

for i in range(len(mum)):
    print(mum[i])

for i,x in enumerate(mum):
    print(i,x)



'''
# Solution 2
def pivotIndex(nums):
    S = sum(nums)
    print(S)
    leftsum = 0
    for i, x in enumerate(nums):
        if leftsum == (S - leftsum - x):
            return i
        leftsum += x
    return -1

nums = [1, 7, 3, 6, 5, 6]
print(pivotIndex(nums))
'''
# Out:
# <class 'list'>
# 71
# 34
# 3
# 41
# 5
# 71
# 34
# 3
# 41
# 5
# 0 71
# 1 34
# 2 3
# 3 41
# 4 5
# '\n# Solution 2\ndef pivotIndex(nums):\n    S = sum(nums)\n    print(S)\n    leftsum = 0\n    for i, x in enumerate(nums):\n        if leftsum == (S - leftsum - x):\n            return i\n        leftsum += x\n    return -1\n\nnums = [1, 7, 3, 6, 5, 6]\nprint(pivotIndex(nums))\n'
