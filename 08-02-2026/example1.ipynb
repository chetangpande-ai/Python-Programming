# %%
"""
multiline comment 1
line1
line2
"""


'''
multiple line comment2
'''
# Out:
# '\nmultiple line comment2\n'

# %%
age=25
print(type(age))
# Out:
# <class 'int'>

# %%
name='chetan'
print(type(name))

name2="chetan pande"
print(type(name2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(13/4)
print(13//4)

print(4**2)
# Out:
# 3.25
# 3
# 16
