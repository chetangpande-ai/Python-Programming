# %%
#list collection
employee_name=['amit','raju','rakesh']

for employee in employee_name:
    if employee.startswith('a'):
        print(employee)
# Out:
# amit

# %%
#dictionary
student_details={1:{"name":"ishan", "class":8},
                 2:{"name":"raju","class":7}}

print((student_details[1])["name"])
# Out:
# ishan

# %%
#tuple
address=("d704","silver crescent", "pune",411014, 'm')

for value in address:
    print(value)
# Out:
# d704
# silver crescent
# pune
# 411014
# m
