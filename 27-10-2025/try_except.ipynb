# %%
try:
    a=10/0
    print('division completed')
except:
    print('exception occured')
finally:
    print('in finally block')
# Out:
# exception occured
# in finally block

# %%
try:
    a=10/0
    print('division completed')
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
a=input('enter value')
print(a)
# Out:
# 12
