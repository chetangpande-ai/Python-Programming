# %% [markdown]
# ### class1, class2 exnteded by class3

# %%
class student():
    def printName(self):
        print("student class")

class orbis_student():
    def print_orbis_student(self):
        print("print orbis student")

class bishop_student(student,orbis_student):
    def prin_bishop_student(self):
        print("bishop_student")

# %%
b1 = bishop_student()
b1.prin_bishop_student()
b1.printName()
b1.print_orbis_student()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 b1 = bishop_student()
# ----> 2 b1.prin_bishop_student()
#       3 b1.printName()
#       4 b1.print_orbis_student()
#
# TypeError: bishop_student.prin_bishop_student() takes 0 positional arguments but 1 was given
