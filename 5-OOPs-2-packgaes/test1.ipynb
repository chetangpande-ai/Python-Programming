# %%
from hospital.checkup import *

# %%
print_checkup()
# Out:
# checkup

# %%
from hospital.admission.util import *

# %%
add(5,7)
# Out:
# 12

# %%
from hospital.admission import util

# %%
util.add(66,44)
