# %%
import os

# %%
print(os.path.abspath(".."))
print(os.path.abspath("../"))
# Out:
# d:\Chetan Pande\AI-ML-2025\Python_Practise\Python-Programming\5-OOPs-2-packgaes
# d:\Chetan Pande\AI-ML-2025\Python_Practise\Python-Programming\5-OOPs-2-packgaes

# %%
print(os.path.abspath("."))
# Out:
# d:\Chetan Pande\AI-ML-2025\Python_Practise\Python-Programming\5-OOPs-2-packgaes\dummy

# %%
print(os.path.abspath("d:/Chetan Pande/AI-ML-2025/Python_Practise/Python-Programming"))
# Out:
# d:\Chetan Pande\AI-ML-2025\Python_Practise\Python-Programming
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Ishan Pande\AppData\Local\Temp\ipykernel_28580\1693988828.py:1: SyntaxWarning: invalid escape sequence '\C'
#   print(os.path.abspath("d:\Chetan Pande\AI-ML-2025\Python_Practise\Python-Programming"))
