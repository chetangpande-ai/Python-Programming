# %%
class Robot:
    
    def __init__(self,name:str,cost:int):
        self.name = name
        self.type = "Robot"
        self.year = 2024
        self.cost = cost

    def say_hi(self,localvarialble=None):
        lolcal=localvarialble
        print(f"Hi, I am {self.name}, a {self.type} from the year {self.year} and cost is {self.cost}")


if __name__ == "__main__":
    r1 = Robot("R2-D2",3000)
    r1.year = 2025
    r1.cost = 1000
    r1.say_hi("This is a local variable")
    print(r1.year)
# Out:
# Hi, I am R2-D2, a Robot from the year 2025 and cost is 1000
# 2025
