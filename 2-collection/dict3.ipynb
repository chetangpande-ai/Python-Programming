# %% [markdown]
# Dictonary

# %%
society={"D":{"704":"chetan pande","703":"Jash"},
"C":{"704":"Hirappa","703":"amit"}
}

# %%
society
# Out:
# {'D': {'704': 'chetan pande', '703': 'Jash'},
#  'C': {'704': 'Hirappa', '703': 'amit'}}

# %%
society.get("D").get("704")
# Out:
# 'chetan pande'
